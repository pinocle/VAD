# %%
from scipy import io

# %%
mat_file=io.loadmat("../data/01_raw/Avenue Dataset/testing_vol/vol01.mat")

# %%
mat_file
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sat Nov 30 13:49:47 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'vol': array([[[ 42,  41,  42, ...,  41,  41,  41],
#          [ 44,  43,  44, ...,  43,  42,  42],
#          [ 46,  46,  46, ...,  45,  45,  44],
#          ...,
#          [236, 215, 226, ..., 205, 204, 206],
#          [230, 206, 215, ..., 197, 196, 198],
#          [222, 199, 207, ..., 190, 188, 191]],
#
#         [[ 35,  33,  34, ...,  35,  33,  33],
#          [ 38,  37,  37, ...,  37,  36,  36],
#          [ 40,  39,  40, ...,  39,  38,  38],
#          ...,
#          [149, 142, 145, ..., 143, 143, 143],
#          [147, 139, 142, ..., 142, 142, 142],
#          [143, 137, 140, ..., 141, 141, 141]],
#
#         [[ 31,  31,  30, ...,  30,  30,  30],
#          [ 34,  34,  34, ...,  34,  34,  34],
#          [ 37,  37,  37, ...,  36,  36,  36],
#          ...,
#          [128, 122, 125, ..., 125, 125, 125],
# ...
